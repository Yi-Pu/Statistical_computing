# %%
# Import moduls
from tree_builder import new_treemap, treemap_insert, treemap_search, treemap_search_between

# %%
# Test some examples
example = new_treemap(4, "ducks")
treemap_insert(example, 3, "walruses")
treemap_insert(example, 3.5, "penguins")
treemap_insert(example, 2, "seals")
treemap_insert(example, 5, "whales")
treemap_insert(example, 4.5, "otters")

# %%
example.show()
# Out:
# 4: ducks
# left:
#   3: walruses
#   left:
#     2: seals
#   right:
#     3.5: penguins
# right:
#   5: whales
#   left:
#     4.5: otters

# %%
treemap_search(example, 5)
# Out:
# 'whales'

# %%
treemap_search_between(example, -1, 5.1)
# Out:
# ['seals', 'walruses', 'penguins', 'ducks', 'otters', 'whales']

# %%
# Test some examples
example2 = new_treemap(0, "apple")
treemap_insert(example2, -1, "pear")
treemap_insert(example2, -1, "pineapple")
treemap_insert(example2, -1, "watermellon")
treemap_insert(example2, 9, "orange")
treemap_insert(example2, -3.4, "berry")
treemap_insert(example2, 5, "mango")

# %%
example2.show()
# Out:
# 0: apple
# left:
#   -1: watermellon
#   left:
#     -3.4: berry
# right:
#   9: orange
#   left:
#     5: mango

# %%
treemap_search(example2, -1)
# Out:
# 'watermellon'

# %%
treemap_search_between(example2, -3.4, 5)
# Out:
# ['berry', 'watermellon', 'apple']
